# %%
import pandas as pd

# %%
df = pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df.isnull()
# Out:
#         Year   City  Sport  Discipline  Athlete  Country  Gender  Event  Medal
# 0      False  False  False       False    False    False   False  False  False
# 1      False  False  False       False    False    False   False  False  False
# 2      False  False  False       False    False    False   False  False  False
# 3      False  False  False       False    False    False   False  False  False
# 4      False  False  False       False    False    False   False  False  False
# ...      ...    ...    ...         ...      ...      ...     ...    ...    ...
# 31160  False  False  False       False    False    False   False  False  False
# 31161  False  False  False       False    False    False   False  False  False
# 31162  False  False  False       False    False    False   False  False  False
# 31163  False  False  False       False    False    False   False  False  False
# 31164  False  False  False       False    False    False   False  False  False
#
# ...

# %%
df.isnull().sum()          #how many null values are there in the dataset
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       4
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %%
#how many unique city
df['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# # 1. *Hence Total 22 cities summer olympic is held so far*

# %%
for City in df['City'].unique():
    print(City, ":", len(df[df['City'] == City]))      #it will return all the City with their Frequency
# Out:
# Athens : 2149
# Paris : 1396
# St Louis : 470
# London : 3567
# Stockholm : 885
# Antwerp : 1298
# Amsterdam : 710
# Los Angeles : 2074
# Berlin : 875
# Helsinki : 889
# Melbourne / Stockholm : 885
# Rome : 882
# Tokyo : 1010
# Mexico : 1031
# Munich : 1185
# Montreal : 1305
# Moscow : 1387
# Seoul : 1546
# Barcelona : 1705
# Atlanta : 1859
# Sydney : 2015
# Beijing : 2042

# %% [markdown]
# # London is the city which held the summer olympic most times

# %%
for Medal in df['Medal'].unique():
    print(Medal, ":", len(df[df['Medal'] == Medal]))
# Out:
# Gold : 10486
# Silver : 10310
# Bronze : 10369

# %%
data = []
for Medal in df['Medal'].unique():
    data.append([Medal, len(df[df['Medal'] ==Medal ])])
data = pd.DataFrame(data, columns = ['Medal','freq'])

# %%
data=data.sort_values(by='freq', ascending=False).head()

# %%
data.plot(x='Medal', y='freq', kind='bar', figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Medal'>

# %%
for Sport in df['Sport'].unique():
    print(Sport, ":", len(df[df['Sport'] == Sport]))
# Out:
# Aquatics : 4170
# Athletics : 3638
# Cycling : 1105
# Fencing : 1613
# Gymnastics : 2307
# Shooting : 1150
# Tennis : 296
# Weightlifting : 593
# Wrestling : 1212
# Archery : 329
# Basque Pelota : 4
# Cricket : 24
# Croquet : 8
# Equestrian : 939
# Football : 1497
# Golf : 30
# Polo : 66
# Rowing : 2667
# Rugby : 192
# Sailing : 1109
# Tug of War : 94
# Boxing : 894
# Lacrosse : 59
# Roque : 3
# Hockey : 1422
# Jeu de paume : 3
# Rackets : 10
# Skating : 27
# Water Motorsports : 5
# Modern Pentathlon : 180
# Ice Hockey : 27
# Basketball : 1012
# Canoe / Kayak : 1002
# Handball : 973
# Judo : 491
# Volleyball : 994
# Table Tennis : 144
# Badminton : 144
# Baseball : 335
# Softball : 180
# Taekwondo : 112
# Triathlon : 24
# Canoe : 81

# %%
for Gender in df['Gender'].unique():
    print(Gender, ":", len(df[df['Gender'] == Gender]))
# Out:
# Men : 22746
# Women : 8419

# %%
df[df['Medal']  == 'Gold']
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
df[df['Gender']  == 'Women']
# Out:
#        Year    City      Sport           Discipline                   Athlete  \
# 416    1900   Paris       Golf                 Golf              PRATT, Daria
# 417    1900   Paris       Golf                 Golf     ABBOTT, Margaret Ives
# 418    1900   Paris       Golf                 Golf         WHITTIER, Pauline
# 639    1900   Paris     Tennis               Tennis             JONES, Marion
# 640    1900   Paris     Tennis               Tennis         ROSENBAUM, Hedwig
# ...     ...     ...        ...                  ...                       ...
# 31116  2012  London  Wrestling  Wrestling Freestyle           VOLOSOVA, Lubov
# 31121  2012  London  Wrestling  Wrestling Freestyle        VOROBIEVA, Natalia
# 31122  2012  London  Wrestling  Wrestling Freestyle  HRISTOVA, Stanka Zlateva
# 31123  2012  London  Wrestling  Wrestling Freestyle          MANYUROVA, Guzel
# 31124  2012  London  Wrestling  Wrestling Freestyle              UNDA, Maider
#
# ...

# %%
df[df['Medal']=='Gold'].sort_values(by='Medal', ascending=False).head()
# Out:
#        Year       City       Sport   Discipline                    Athlete  \
# 0      1896     Athens    Aquatics     Swimming              HAJOS, Alfred
# 20557  1992  Barcelona  Gymnastics  Artistic G.            BELENKI, Valeri
# 20499  1992  Barcelona    Football     Football      GUARDIOLA SALA, Josep
# 20500  1992  Barcelona    Football     Football  JIMENEZ SISTACHS, Antonio
# 20501  1992  Barcelona    Football     Football     LASA GOICOECHEA, Mikel
#
#       Country Gender             Event Medal
# 0         HUN    Men    100M Freestyle  Gold
# 20557     EUN    Men  Team Competition  Gold
# 20499     ESP    Men          Football  Gold
# 20500     ESP    Men          Football  Gold
# 20501     ESP    Men          Football  Gold

# %%
df[df['Medal']=='Gold']
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
df = pd.read_csv("summer.csv")

df = df[df['Gender']=='Women']

for Sport in df['Gender'].unique():
    data.append([Gender, len(df[df['Gender']==Gender])])
    
pd.DataFrame(data,columns = ['Gender', 'freq']).sort_values(by='Gender', ascending=False)
# Out:
#    Gender   freq
# 0     NaN  10486
# 2     NaN  10369
# 1     NaN  10310

# %%
df = pd.read_csv("summer.csv")

df = df[df['Country']=='IND']
df = df[df['Medal']=='Gold']

# %%
df['Year'].min()            #In 1928 india won the first gold medal
# Out:
# 1928

# %% [markdown]
# # 6. In 1928 India won the first gold medal

# %%
df = pd.read_csv("summer.csv")

df = df[df['Medal']=='Gold']

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
gold_avg = df.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head()

# %%
gold_avg
# Out:
# Athlete
# PHELPS, Michael     18
# LEWIS, Carl          9
# NURMI, Paavo         9
# SPITZ, Mark          9
# LATYNINA, Larisa     9
# Name: Medal, dtype: int64

# %%
gold_avg.plot.bar(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# # 5. PHELPS, Michael  wins the most number of gold medals

# %%
df = pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
medal_avg = df.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head()

# %%
medal_avg.plot.bar(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# # 4. PHELPS, Michael has most number of medals

# %%
medal_avg
# Out:
# Athlete
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# ONO, Takashi            13
# Name: Medal, dtype: int64

# %%
df = pd.read_csv("summer.csv")

# %%
for Event in df['Event'].unique():
    print(Event, ":", len(df[df['Event'] == Event]))
# Out:
# 100M Freestyle : 148
# 100M Freestyle For Sailors : 3
# 1200M Freestyle : 3
# 400M Freestyle : 144
# 100M : 142
# 110M Hurdles : 80
# 1500M : 114
# 400M : 119
# 800M : 126
# Discus Throw : 141
# High Jump : 151
# Long Jump : 132
# Marathon : 105
# Pole Vault : 100
# Shot Put : 132
# Triple Jump : 96
# Individual Road Race : 76
# 100KM : 5
# 10KM : 9
# 12-Hour Race : 2
# 1KM Time Trial : 57
# Sprint Indivual : 69
# Foil Individual : 141
# Foil, Masters : 5
# Sabre Individual : 90
# Horizontal Bar : 72
# Parallel Bars : 72
# Pommel Horse : 69
# Rings : 73
# Rope Climbing : 13
# Team, Horizontal Bar : 11
# Team, Parallel Bars : 19
# Vault : 123
# 25M Army Pistol : 3
# 25M Rapid Fire Pistol (60 Shots) : 69
# 50M Pistol (60 Shots) : 66
# Army Rifle, 200M : 3
# Army Rifle, 300M : 3
# Doubles : 318
# Singles : 168
# Heavyweight - One Hand Lift : 3
# Heavyweight - Two Hand Lift : 6
# Open Event : 3
# 1500M Freestyle : 78
# 200M Backstroke : 79
# 200M Freestyle : 78
# 200M Obstacle Event : 3
# ...

# %%
event_avg = df.groupby('Event').count()['Athlete'].sort_values(ascending=False)

# %%
event_avg_ = event_avg.head()

# %%
event_avg_.plot.bar(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Event'>

# %% [markdown]
# # 7. Football is the most popular in terms on number of players

# %%
df = pd.read_csv("summer.csv")

# %%
df = df[df['Medal']=='Gold']

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
Sport_gold_avg = df.groupby('Sport').count()['Medal'].sort_values(ascending=False)

# %%
Sport_gold_avg_top = Sport_gold_avg.head()

# %%
Sport_gold_avg_top
# Out:
# Sport
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Medal, dtype: int64

# %%
Sport_gold_avg_top.plot.bar(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# # 2. Aquatics has most number of gold medal so far

# %%
df = pd.read_csv("summer.csv")

df = df[df['Gender']=='Women']
df = df[df['Medal']=='Gold']

# %%
df
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
Spor_femalet_gold_avg = df.groupby('Sport').count()['Medal'].sort_values(ascending=False).head()

# %%
Spor_femalet_gold_avg
# Out:
# Sport
# Aquatics      589
# Athletics     389
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Medal, dtype: int64

# %%
Spor_femalet_gold_avg.plot.bar(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# # 8. In Aquatics Event, there are most female gold medalist

# %%
df = pd.read_csv("summer.csv")
total_medal_sport_avg = df.groupby('Sport').count()['Medal'].sort_values(ascending=False).head()

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
total_medal_sport_avg.plot.bar(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# # 3. Aquatics Event Has most number of medals so far
